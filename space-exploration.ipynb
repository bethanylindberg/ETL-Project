# %%
#Transform Dependencies
import pandas as pd
import numpy as np
import datetime as dt
import dateutil.parser
import re
import json
from pprint import pprint

#Visualizations
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns

# Python SQL toolkit and Object Relational Mapper
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, func, inspect, Table, MetaData

# %%
from config import rds_connection_string
engine = create_engine(f'mysql+mysqlconnector://{rds_connection_string}')
session = Session(engine)
inspector = inspect(engine)
inspector.get_table_names()
metadata = MetaData(bind=None)

# %% [markdown]
# # Launches (No Nan)

# %%
launch_log = pd.read_sql_query('SELECT * FROM launch_log;', con=engine).dropna()
launch_log.head()
# Out:
#      launch      launch_date_utc      COSPAR     pl_name  \
# 0  1957 ALP   1957 Oct 4 1928:34  1957 ALP 2     1-y ISZ
# 1  1957 BET   1957 Nov 3 0230:42  1957 BET 1     2-y ISZ
# 2  1958 ALP   1958 Feb 1 0347:56    1958 ALP  Explorer 1
# 3  1958 BET  1958 Mar 17 1215:41  1958 BET 2  Vanguard I
# 4  1958 GAM  1958 Mar 26 1738:03    1958 GAM  Explorer 3
#
#               orig_pl_name  SATCAT         lv_type     lv_sn        site suc  \
# 0                     PS-1  S00002  Sputnik 8K71PS     M1-PS  NIIP-5 LC1   S
# 1                     PS-2  S00003  Sputnik 8K71PS    M1-2PS  NIIP-5 LC1   S
# 2               Explorer 1  S00004       Jupiter C  RS-29 UE    CC LC26A   S
# 3  Vanguard Test Satellite  S00005        Vanguard      TV-4    CC LC18A   S
# 4               Explorer 3  S00006       Jupiter C  RS-24 UT      CC LC5   S
#
#          Ref launch_date
# 0   Energiya  1957-10-04
# 1  Grahn-WWW  1957-11-03
# 2    JunoFam  1958-02-01
# 3    SP-4202  1958-03-01
# 4    JunoFam  1958-03-02

# %%
launch_log["Year"] = launch_log['launch_date'].map(lambda x: int(x.strftime('%Y')))
launch_log2 = launch_log[launch_log["Year"] != 2019]

x_axis = launch_log2.groupby('Year')['Year'].max()
launches = launch_log2.groupby('Year')['Year'].count()
plt.figure(figsize = (15,10))

plt.plot(x_axis, launches)
plt.xlabel("Year")
plt.ylabel("Total Launches")
plt.grid(True,alpha=.5)

plt.title("Launches Over Time")

# plt.savefig('.\\Output\\launchessovertime.png')
plt.show()

# %% [markdown]
# # Total Launches

# %%
launch_log = pd.read_sql_query('SELECT * FROM launch_log;', con=engine)
launch_log.head()
# Out:
#      launch      launch_date_utc      COSPAR     pl_name  \
# 0  1957 ALP   1957 Oct 4 1928:34  1957 ALP 2     1-y ISZ
# 1  1957 BET   1957 Nov 3 0230:42  1957 BET 1     2-y ISZ
# 2  1958 ALP   1958 Feb 1 0347:56    1958 ALP  Explorer 1
# 3  1958 BET  1958 Mar 17 1215:41  1958 BET 2  Vanguard I
# 4  1958 GAM  1958 Mar 26 1738:03    1958 GAM  Explorer 3
#
#               orig_pl_name  SATCAT         lv_type     lv_sn        site suc  \
# 0                     PS-1  S00002  Sputnik 8K71PS     M1-PS  NIIP-5 LC1   S
# 1                     PS-2  S00003  Sputnik 8K71PS    M1-2PS  NIIP-5 LC1   S
# 2               Explorer 1  S00004       Jupiter C  RS-29 UE    CC LC26A   S
# 3  Vanguard Test Satellite  S00005        Vanguard      TV-4    CC LC18A   S
# 4               Explorer 3  S00006       Jupiter C  RS-24 UT      CC LC5   S
#
#          Ref launch_date
# 0   Energiya  1957-10-04
# 1  Grahn-WWW  1957-11-03
# 2    JunoFam  1958-02-01
# 3    SP-4202  1958-03-01
# 4    JunoFam  1958-03-02

# %%
launch_log["Year"] = launch_log['launch_date'].map(lambda x: int(x.strftime('%Y')))
launch_log2 = launch_log[launch_log["Year"] != 2019]

x_axis = launch_log2.groupby('Year')['Year'].max()
launches = launch_log2.groupby('Year')['Year'].count()
plt.figure(figsize = (15,10))

plt.plot(x_axis, launches)
plt.xlabel("Year")
plt.ylabel("Total Launches")
plt.grid(True,alpha=.5)

plt.title("Launches Over Time")

# plt.savefig('.\\Output\\launchessovertime.png')
plt.show()

# %% [markdown]
# # Launces over time and total launches by top 5 countries

# %%
satellites = pd.read_sql_query('SELECT * FROM ucs_satellites;', con=engine)
satellites["Year"] = satellites['launch_date'].map(lambda x: int(x.strftime('%Y')))
satellites = satellites[satellites["Year"] != 2019]


satellitesc = satellites.groupby(["country","Year"])["Year"].count()

# Convert to DataFrame
satellitesdf = pd.DataFrame(satellitesc)

# # Minor Data Munging to Re-Format the Data Frames
satdf = satellitesdf.unstack(level=0)
satdf.columns = [x[1] for x in satdf.columns]

satdf.head()
# Out:
#       Algeria  Argentina  Australia  Austria  Azerbaijan  Bangladesh  Belarus  \
# Year
# 1974      NaN        NaN        NaN      NaN         NaN         NaN      NaN
# 1988      NaN        NaN        NaN      NaN         NaN         NaN      NaN
# 1989      NaN        NaN        NaN      NaN         NaN         NaN      NaN
# 1990      NaN        NaN        NaN      NaN         NaN         NaN      NaN
# 1991      NaN        NaN        NaN      NaN         NaN         NaN      NaN
#
#       Belgium  Bhutan  Bolivia  ...  USA/Korea  USA/United Kingdom/Italy  \
# Year                            ...
# 1974      NaN     NaN      NaN  ...        NaN                       NaN
# 1988      NaN     NaN      NaN  ...        NaN                       NaN
# 1989      NaN     NaN      NaN  ...        NaN                       NaN
# 1990      NaN     NaN      NaN  ...        NaN                       NaN
# 1991      NaN     NaN      NaN  ...        NaN                       NaN
#
#       Ukraine  Ukraine/China  United Arab Emirates  United Kingdom  \
# Year
# 1974      NaN            NaN                   NaN             NaN
# 1988      NaN            NaN                   NaN             NaN
# 1989      NaN            NaN                   NaN             NaN
# 1990      NaN            NaN                   NaN             5.0
# 1991      NaN            NaN                   NaN             NaN
#
#       United Kingdom/ESA  Uruguay  Venezuela  Vietnam
# Year
# 1974                 NaN      NaN        NaN      NaN
# 1988                 NaN      NaN        NaN      NaN
# 1989                 NaN      NaN        NaN      NaN
# 1990                 NaN      NaN        NaN      NaN
# 1991                 NaN      NaN        NaN      NaN
#
# [5 rows x 101 columns]

# %%
plt.figure(figsize = (15,10))
plt.grid(b=True)

countries = ["USA", "China", "Russia", "Japan","India"]

counter = 0
for column in range(5):
    plt.plot(satdf.index, satdf[countries[counter]],linewidth=2)
    counter +=1

#Incorporate the other graph properties    
plt.xlabel("Year")
plt.ylabel("Total Launches")
plt.grid(True,alpha=.5)
plt.title("Launches Over Time by Top 5 Countries")
plt.legend(loc=2, fontsize="large")

# Save the Figure

plt.show()

# %%
x = pd.read_sql_query('SELECT YEAR(launch_date)as Year,country as Country\
                        FROM ucs_satellites\
                        WHERE Country in ("USA","China","Russia","Japan","India");', con=engine).dropna()
x.head()
# Out:
#    Year Country
# 0  2018     USA
# 1  2018     USA
# 2  2018     USA
# 3  2018     USA
# 4  2018     USA

# %%
cmap = 'PuBuGn'
sns.catplot("Country",kind="count",data=x,palette=cmap)
plt.title("Total Launches by Top 5 Countries")
# Out:
# Text(0.5, 1.0, 'Total Launches by Top 5 Countries')

# %%
purpose = pd.read_sql_query('SELECT * FROM ucs_satellites;', con=engine)
purpose["Year"] = purpose['launch_date'].map(lambda x: int(x.strftime('%Y')))
purpose = purpose[purpose["Year"] != 2019]
#Remove trailing whitespace
purpose["purpose"] = purpose["purpose"].str.strip()

purpose["purpose"].value_counts()
# Out:
# Communications                                    3800
# Earth Observation                                 3495
# Technology Development                            1050
# Navigation/Global Positioning                      625
# Space Science                                      375
# Earth Science                                      115
# Technology Demonstration                            60
# Navigation/Regional Positioning                     60
# Communications/Technology Development               50
# Space Observation                                   45
# Earth Observation/Technology Development            35
# Communications/Maritime Tracking                    25
# Earth Observation/Communications                    10
# Technology Development/Educational                   5
# Communications/Earth Observation                     5
# Space Science/Technology Development                 5
# Earth Observation/Space Science                      5
# Earth Science/Earth Observation                      5
# Communications/Navigation                            5
# Earth Observation/Communications/Space Science       5
# Earth Science/Space Science                          5
# Name: purpose, dtype: int64

# %%
purposegroup = purpose.groupby(["purpose","Year"])["Year"].count()

# Convert to DataFrame
purposedf = pd.DataFrame(purposegroup)

# # Minor Data Munging to Re-Format the Data Frames
pdf = purposedf.unstack(level=0)
pdf.columns = [x[1] for x in pdf.columns]

pdf.head()
# Out:
#       Communications  Communications/Earth Observation  \
# Year
# 1974             5.0                               NaN
# 1988             5.0                               NaN
# 1989             5.0                               NaN
# 1990             5.0                               NaN
# 1991             5.0                               NaN
#
#       Communications/Maritime Tracking  Communications/Navigation  \
# Year
# 1974                               NaN                        NaN
# 1988                               NaN                        NaN
# 1989                               NaN                        NaN
# 1990                               NaN                        NaN
# 1991                               NaN                        NaN
#
#       Communications/Technology Development  Earth Observation  \
# Year
# 1974                                    NaN                NaN
# 1988                                    NaN                NaN
# 1989                                    NaN                NaN
# 1990                                    NaN                NaN
# 1991                                    NaN                NaN
#
#       Earth Observation/Communications  \
# Year
# 1974                               NaN
# 1988                               NaN
# 1989                               NaN
# 1990                               NaN
# 1991                               NaN
#
#       Earth Observation/Communications/Space Science  \
# Year
# 1974                                             NaN
# 1988                                             NaN
# 1989                                             NaN
# 1990                                             NaN
# 1991                                             NaN
#
#       Earth Observation/Space Science  \
# Year
# 1974                              NaN
# 1988                              NaN
# 1989                              NaN
# 1990                              NaN
# 1991                              NaN
#
#       Earth Observation/Technology Development  ...  \
# Year                                            ...
# 1974                                       NaN  ...
# 1988                                       NaN  ...
# 1989                                       NaN  ...
# 1990                                       NaN  ...
# 1991                                       NaN  ...
#
#       Earth Science/Earth Observation  Earth Science/Space Science  \
# Year
# 1974                              NaN                          NaN
# 1988                              NaN                          NaN
# 1989                              NaN                          NaN
# 1990                              NaN                          NaN
# 1991                              NaN                          NaN
#
#       Navigation/Global Positioning  Navigation/Regional Positioning  \
# Year
# 1974                            NaN                              NaN
# 1988                            NaN                              NaN
# 1989                            NaN                              NaN
# 1990                            NaN                              NaN
# 1991                            NaN                              NaN
#
#       Space Observation  Space Science  Space Science/Technology Development  \
# Year
# 1974                NaN            NaN                                   NaN
# 1988                NaN            NaN                                   NaN
# 1989                NaN            NaN                                   NaN
# 1990                NaN            5.0                                   NaN
# 1991                NaN            NaN                                   NaN
#
#       Technology Demonstration  Technology Development  \
# Year
# 1974                       NaN                     NaN
# 1988                       NaN                     NaN
# 1989                       NaN                     NaN
# 1990                       NaN                     NaN
# 1991                       NaN                     NaN
#
#       Technology Development/Educational
# Year
# 1974                                 NaN
# 1988                                 NaN
# 1989                                 NaN
# 1990                                 NaN
# 1991                                 NaN
#
# [5 rows x 21 columns]

# %%
plt.figure(figsize = (15,10))
plt.grid(b=True)

for column in pdf:
    plt.plot(pdf.index, pdf[column],linewidth=2)

#Incorporate the other graph properties    
plt.xlabel("Year")
plt.ylabel("Total Launches")
plt.grid(True,alpha=.5)
plt.title("Launches Over Time by Purpose")
plt.legend(loc=2, fontsize="large")

# Save the Figure

plt.show()

# %%
p = sns.catplot("purpose",kind="count",data=purpose,palette=cmap)
p.set_xticklabels(rotation=30)
plt.title("Total Launches by Purpose")
plt.show()

# %%
purpose["purpose"] = purpose["purpose"].replace(
    {'Navigation/Global Positioning':'Navigation','Navigation/Regional Positioning':'Navigation',
    'Communications/Technology Development':'Communications','Earth Observation/Technology Development':'Earth Observation',
    'Communications/Maritime Tracking':'Communications','Earth Science/Earth Observation':'Earth Science',
    'Earth Observation/Communications':'Earth Observation','Technology Development/Educational':'Technology Development',
    'Earth Observation/Space Science':'Earth Observation','Earth Observation/Communications/Space Science':'Earth Observation',
    'Communications/Navigation':'Communications','Earth Science/Space Science':'Earth Science',
    'Earth Science/Space Science':'Earth Science','Earth Science/Space Science':'Earth Science',
    'Space Science/Technology Development':'Space Science','Communications/Earth Observation':'Communications',})

# %%
purpose["purpose"].value_counts()
# Out:
# Communications              3885
# Earth Observation           3550
# Technology Development      1055
# Navigation                   685
# Space Science                380
# Earth Science                125
# Technology Demonstration      60
# Space Observation             45
# Name: purpose, dtype: int64

# %%
purposegroup = purpose.groupby(["purpose","Year"])["Year"].count()

# Convert to DataFrame
purposedf = pd.DataFrame(purposegroup)

# # Minor Data Munging to Re-Format the Data Frames
pdf = purposedf.unstack(level=0)
pdf.columns = [x[1] for x in pdf.columns]

pdf.head()
# Out:
#       Communications  Earth Observation  Earth Science  Navigation  \
# Year
# 1974             5.0                NaN            NaN         NaN
# 1988             5.0                NaN            NaN         NaN
# 1989             5.0                NaN            NaN         NaN
# 1990             5.0                NaN            NaN         NaN
# 1991             5.0                NaN            NaN         NaN
#
#       Space Observation  Space Science  Technology Demonstration  \
# Year
# 1974                NaN            NaN                       NaN
# 1988                NaN            NaN                       NaN
# 1989                NaN            NaN                       NaN
# 1990                NaN            5.0                       NaN
# 1991                NaN            NaN                       NaN
#
#       Technology Development
# Year
# 1974                     NaN
# 1988                     NaN
# 1989                     NaN
# 1990                     NaN
# 1991                     NaN

# %%
plt.figure(figsize = (15,10))
plt.grid(b=True)

for column in pdf:
    plt.plot(pdf.index, pdf[column],linewidth=2)

#Incorporate the other graph properties    
plt.xlabel("Year")
plt.ylabel("Total Launches")
plt.grid(True,alpha=.5)
plt.title("Launches Over Time by Purpose")
plt.legend(loc=2, fontsize="large")

# Save the Figure

plt.show()

# %%
p = sns.catplot("purpose",kind="count",data=purpose,palette=cmap)
p.set_xticklabels(rotation=30)
plt.title("Total Launches by Purpose")
plt.show()

# %%
user = pd.read_sql_query('SELECT * FROM ucs_satellites;', con=engine)
user["Year"] = user['launch_date'].map(lambda x: int(x.strftime('%Y')))
user["users"] = user["users"].str.strip()

user = user[user["Year"] != 2019]


user["users"].value_counts()
# Out:
# Commercial                        4230
# Government                        1925
# Military                          1510
# Civil                              725
# Government/Commercial              605
# Military/Commercial                360
# Military/Government                225
# Government/Civil                   140
# Government/Military                 25
# Military/Civil                      15
# Commercial/Military                 10
# Civil/Government                    10
# Government/Commercial/Military       5
# Name: users, dtype: int64

# %%
usergroup = user.groupby(["users","Year"])["Year"].count()

# Convert to DataFrame
userdf = pd.DataFrame(usergroup)

# # Minor Data Munging to Re-Format the Data Frames
udf = userdf.unstack(level=0)
udf.columns = [x[1] for x in udf.columns]

udf.head()
# Out:
#       Civil  Civil/Government  Commercial  Commercial/Military  Government  \
# Year
# 1974    5.0               NaN         NaN                  NaN         NaN
# 1988    NaN               NaN         NaN                  NaN         5.0
# 1989    NaN               NaN         NaN                  NaN         NaN
# 1990    NaN               NaN         NaN                  NaN         5.0
# 1991    NaN               NaN         NaN                  NaN         NaN
#
#       Government/Civil  Government/Commercial  Government/Commercial/Military  \
# Year
# 1974               NaN                    NaN                             NaN
# 1988               NaN                    NaN                             NaN
# 1989               NaN                    NaN                             NaN
# 1990               NaN                    NaN                             NaN
# 1991               NaN                    5.0                             NaN
#
#       Government/Military  Military  Military/Civil  Military/Commercial  \
# Year
# 1974                  NaN       NaN             NaN                  NaN
# 1988                  NaN       NaN             NaN                  NaN
# 1989                  NaN       5.0             NaN                  NaN
# 1990                  NaN       5.0             NaN                  NaN
# 1991                  NaN       NaN             NaN                  NaN
#
#       Military/Government
# Year
# 1974                  NaN
# 1988                  NaN
# 1989                  NaN
# 1990                  NaN
# 1991                  NaN

# %%
plt.figure(figsize = (15,10))
plt.grid(b=True)

for column in udf:
    plt.plot(udf.index, udf[column],linewidth=2)

#Incorporate the other graph properties    
plt.xlabel("Year")
plt.ylabel("Total Launches")
plt.grid(True,alpha=.5)
plt.title("Launches Over Time by Users")
plt.legend(loc=2, fontsize="large")

# Save the Figure

plt.show()

# %%
p = sns.catplot("users",kind="count",data=user,palette=cmap)
p.set_xticklabels(rotation=30)
plt.title("Total Launches by User")
plt.show()
