# %%
# %matplotlib inline
import pandas as pd
import numpy as np
from pandas import DataFrame,Series
import re
import datetime as dt
import dateutil.parser
from sqlalchemy import create_engine

# File to Load
spacex = pd.read_csv('.\\Resources\\spaceX.csv')
nasa = pd.read_csv('.\\Resources\\NASA_Facilities.csv')

# Read into DataFrame
spacexdf = (spacex)
nasadf = (nasa)

# %%
spacexdf.head()
# Out:
#    Flight Number        Launch Date Launch Time                  Launch Site  \
# 0           F1-1      24 March 2006       22:30             Marshall Islands
# 1           F1-2      21 March 2007       01:10             Marshall Islands
# 2           F1-3      3 August 2008       03:34             Marshall Islands
# 3           F1-3      3 August 2008       03:34             Marshall Islands
# 4           F1-3      3 August 2008       03:34             Marshall Islands
# 5           F1-4  28 September 2008       23:15             Marshall Islands
# 6           F1-5       14 July 2009       03:35             Marshall Islands
# 7           F9-1        4 June 2010       18:45     Cape Canaveral AFS LC-40
# 8           F9-2    8 December 2010       15:43     Cape Canaveral AFS LC-40
# 9           F9-3        22 May 2012       07:44     Cape Canaveral AFS LC-40
# 10          F9-4     8 October 2012       00:35     Cape Canaveral AFS LC-40
# ...

# %%
#Format Dates to MM/DD/YYYY
spacexdf['Launch Date'] = spacexdf['Launch Date'].map(lambda x: dateutil.parser.parse(x))
spacexdf['Launch Date'] = spacexdf['Launch Date'].map(lambda x: x.strftime('%m/%d/%Y'))

# %%
nasadf.head()
# Out:
#                          Center Center Search Status  \
# 0          Stennis Space Center               Public
# 1          Ames Research Center               Public
# 2   Goddard Space Flight Center               Public
# 3         Glenn Research Center               Public
# 4  Marshall Space Flight Center               Public
#
#                                             Facility  FacilityURL  \
# 0                               Test Stand A-2 #4122          NaN
# 1  N229 - EXPER. AEROTHERMODYNAMIC FAC.: ELECTRIC...          NaN
# 2                       500 WSC: Antenna, 10m S-band          NaN
# 3                Vacuum Facility 11 (VF-11) Bldg. 16          NaN
# 4         Materials Testing & Research Facility 4464          NaN
#
#                  Occupied    Status  \
# 0  01/01/1964 12:00:00 AM  Inactive
# 1  01/01/1961 12:00:00 AM    Active
# 2  01/01/1977 12:00:00 AM    Active
# 3                     NaN    Active
# 4                     NaN    Active
#
# ...

# %%
#Extract Lat and Long from location column into separate columns
latlong = nasadf['Location'].str.strip('()')\
                   .str.split(', ', expand=True)\
                   .rename(columns={0:'Latitude', 1:'Longitude'})

#Remove Zip code and punctuation from location column
latlong['Latitude'] = latlong['Latitude'].map(lambda x: x[-9:])
latlong['Latitude'] = latlong['Latitude'].str.replace('(','')

#Add lat/long to df
nasadf = pd.merge(nasadf, latlong, left_index=True, right_index=True)

#Remove time stamp from occupied, record date and last update columns
nasadf['Record Date'] = nasadf['Record Date'].map(lambda x: dateutil.parser.parse(x))
nasadf['Record Date'] = nasadf['Record Date'].map(lambda x: x.strftime('%m/%d/%Y'))

nasadf['Occupied'] = nasadf['Occupied'].map(lambda x: dateutil.parser.parse(x) if pd.notnull(x) else np.nan)
nasadf['Occupied'] = nasadf['Occupied'].map(lambda x: x.strftime('%m/%d/%Y') if pd.notnull(x) else np.nan)

nasadf['Last Update'] = nasadf['Last Update'].map(lambda x: dateutil.parser.parse(x)if pd.notnull(x) else np.nan)
nasadf['Last Update'] = nasadf['Last Update'].map(lambda x: x.strftime('%m/%d/%Y')if pd.notnull(x) else np.nan)

# Drop unneeded columns
nasadf.drop(['Location','FacilityURL'],axis=1,inplace=True)

# %%
nasadf.head()
# Out:
#                          Center Center Search Status  \
# 0          Stennis Space Center               Public
# 1          Ames Research Center               Public
# 2   Goddard Space Flight Center               Public
# 3         Glenn Research Center               Public
# 4  Marshall Space Flight Center               Public
#
#                                             Facility    Occupied    Status  \
# 0                               Test Stand A-2 #4122  01/01/1964  Inactive
# 1  N229 - EXPER. AEROTHERMODYNAMIC FAC.: ELECTRIC...  01/01/1961    Active
# 2                       500 WSC: Antenna, 10m S-band  01/01/1977    Active
# 3                Vacuum Facility 11 (VF-11) Bldg. 16         NaN    Active
# 4         Materials Testing & Research Facility 4464         NaN    Active
#
#                                         URL Link Record Date Last Update  \
# 0                     http://rockettest.nasa.gov  03/01/1996  04/06/2015
# ...

# %%
# Connect to local database
rds_connection_string = "root:TbotdFrqcmbl8r@127.0.0.1/space_db"
engine = create_engine(f'mysql+pymysql://{rds_connection_string}')

# %%
engine.table_names()
# Out:
# ['launch_log']

# %%
nasadf.to_sql(name='launch_log', con=engine, if_exists='append', index=False)
spacexdf.to_sql(name='launch_log', con=engine, if_exists='append', index=False)
